# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)'
# r= requests.get("https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)")

# %%
r

# %%
r.status_code

# %%
from selenium.webdriver import Chrome

# %%
webdriver = r'/Users/mdavis/Downloads/chromedriver'

# %%
driver = Chrome(webdriver)

# %%
r = driver.get(url)

# %%
driver.page_source
# Out:
# '<html class="client-js ve-not-available" lang="en" dir="ltr"><head>\n<meta charset="UTF-8">\n<title>List of countries by population (United Nations) - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"XlVXxwpAICkAAK4s7-wAAAEO","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_by_population_(United_Nations)","wgTitle":"List of countries by population (United Nations)","wgCurRevisionId":942389290,"wgRevisionId":942389290,"wgArticleId":39707994,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups
# ...

# %%
soup = BeautifulSoup(driver.page_source)

# %%
main_table = soup.find('table', id = 'main')

# %%
main_table.find('thead')
# Out:
# <thead><tr valign="bottom">
# <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending">Country or area
# </th>
# <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending"><a href="/wiki/United_Nations_geoscheme" title="United Nations geoscheme">UN continental<br/>region</a><sup class="reference" id="cite_ref-region_4-0"><a href="#cite_note-region-4">[4]</a></sup>
# </th>
# <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending"><a href="/wiki/United_Nations_geoscheme" title="United Nations geoscheme">UN statistical<br/>region</a><sup class="reference" id="cite_ref-region_4-1"><a href="#cite_note-region-4">[4]</a></sup>
# </th>
# <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending">Population<br/>(1 July 2018)
# </th>
# <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending">Population<br/>(1 July 2019)
# </th>
# ...

# %%
main_table.find('tfoot')
# Out:
# <tfoot><tr>
# <th class="sort bottom" style="text-align:left"><a href="/wiki/World_population" title="World population">World</a></th>
# <th></th>
# <th></th>
# <th style="text-align:right">7,631,091,040</th>
# <th style="text-align:right">7,713,468,100</th>
# <th style="text-align:right"><span data-sort-value="7000108000000000000♠" style="display:none"></span><span style="color:green">+1.08%</span>
# </th></tr></tfoot>

# %%
driver.close()
